# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps
import gmaps.datasets

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("WeatherPy_vacation.csv")
vacation_df
# Out:
#     City_ID             City Country  Max Temp Current Description      Lat  \
# 0         3            Vaini      TO     73.56              Clouds -21.2000
# 1         8            Vaini      TO     73.56              Clouds -21.2000
# 2        11             Asau      RO     67.28              Clouds  46.4333
# 3        28        Eganville      CA     73.51              Clouds  45.5334
# 4        30       Georgetown      MY     78.89              Clouds   5.4112
# 5        31          Rikitea      PF     71.06              Clouds -23.1203
# 6        36       Butaritari      KI     81.46               Clear   3.0707
# 7        39         Thompson      CA     74.28              Clouds  55.7435
# 8        41  Arraial Do Cabo      BR     66.06              Clouds -22.9661
# 9        43        Jamestown      US     74.84              Clouds  42.0970
# 10       44           Pombas      CV     80.38              Clouds  17.1503
# 11       46      Shubarkuduk      KZ     68.58              Clouds  49.1447
# 12       50            Vaini      TO     73.56              Clouds -21.2000
# 13       53             Asau      RO     67.28              Clouds  46.4333
# 14       70        Eganville      CA     73.51              Clouds  45.5334
# 15       72       Georgetown      MY     78.89              Clouds   5.4112
# 16       73          Rikitea      PF     71.06              Clouds -23.1203
# 17       78       Butaritari      KI     81.46               Clear   3.0707
# 18       81         Thompson      CA     74.28              Clouds  55.7435
# 19       83  Arraial Do Cabo      BR     66.06              Clouds -22.9661
# 20       85        Jamestown      US     74.84              Clouds  42.0970
# 21       86           Pombas      CV     80.38              Clouds  17.1503
# 22       88      Shubarkuduk      KZ     68.58              Clouds  49.1447
# 23       92            Vaini      TO     73.56              Clouds -21.2000
# 24       95             Asau      RO     67.28              Clouds  46.4333
# 25      112        Eganville      CA     73.51              Clouds  45.5334
# 26      114       Georgetown      MY     78.89              Clouds   5.4112
# 27      115          Rikitea      PF     71.06              Clouds -23.1203
# 28      120       Butaritari      KI     81.46               Clear   3.0707
# 29      123         Thompson      CA     74.28              Clouds  55.7435
# 30      125  Arraial Do Cabo      BR     66.06              Clouds -22.9661
# 31      127        Jamestown      US     74.84              Clouds  42.0970
# 32      128           Pombas      CV     80.38              Clouds  17.1503
# 33      130      Shubarkuduk      KZ     68.58              Clouds  49.1447
# 34      137           Lompoc      US     83.70              Clouds  34.6391
# 35      140           Liwale      TZ     65.64              Clouds  -9.7667
# 36      142             Hilo      US     84.25              Clouds  19.7297
#
#          Lng                                Hotel Name
# 0  -175.2000                       Keleti Beach Resort
# 1  -175.2000                       Keleti Beach Resort
# 2    26.4000                        Casa Mika Ciobanus
# 3   -77.0994                                  Egan Inn
# 4   100.3354                            Cititel Penang
# 5  -134.9692                           People ThankYou
# 6   172.7902                        Isles Sunset Lodge
# 7   -97.8558                           Burntwood Hotel
# 8   -42.0278                       Pousada Porto Praia
# 9   -79.2353            Hampton Inn & Suites Jamestown
# 10  -25.0201                              Paul Paradis
# 11   56.4872                                    Sirius
# 12 -175.2000                       Keleti Beach Resort
# 13   26.4000                        Casa Mika Ciobanus
# 14  -77.0994                                  Egan Inn
# 15  100.3354                            Cititel Penang
# 16 -134.9692                           People ThankYou
# 17  172.7902                        Isles Sunset Lodge
# 18  -97.8558                           Burntwood Hotel
# 19  -42.0278                       Pousada Porto Praia
# 20  -79.2353            Hampton Inn & Suites Jamestown
# 21  -25.0201                              Paul Paradis
# 22   56.4872                                    Sirius
# 23 -175.2000                       Keleti Beach Resort
# 24   26.4000                        Casa Mika Ciobanus
# 25  -77.0994                                  Egan Inn
# 26  100.3354                            Cititel Penang
# 27 -134.9692                           People ThankYou
# 28  172.7902                        Isles Sunset Lodge
# 29  -97.8558                           Burntwood Hotel
# 30  -42.0278                       Pousada Porto Praia
# 31  -79.2353            Hampton Inn & Suites Jamestown
# 32  -25.0201                              Paul Paradis
# 33   56.4872                                    Sirius
# 34 -120.4579  Holiday Inn Express Lompoc, an IHG Hotel
# 35   37.9333                      Tumaini Tulivu Lodge
# 36 -155.0900                       Hilo Hawaiian Hotel

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """

<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp} °F</dd>
</dl>

"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
locations = vacation_df[["Lat", "Lng"]]
max_temp = vacation_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 4b. Display the figure
map = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig = gmaps.figure()
fig.add_layer(map)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
## Thompson Canada, Jamestown USA, Eganville Canada, Lompoc US.

# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[vacation_df["City"] == "Thompson"]
vacation_end = vacation_df.loc[vacation_df["City"] == "Thompson"]
vacation_stop1 = vacation_df.loc[vacation_df["City"] == "Eganville"]
vacation_stop2 = vacation_df.loc[vacation_df["City"] == "Jamestown"] 
vacation_stop3 = vacation_df.loc[vacation_df["City"] == "Lompoc"]

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = vacation_start["Lat"].to_numpy()[0], vacation_start["Lng"].to_numpy()[0]
end = vacation_end["Lat"].to_numpy()[0], vacation_end["Lng"].to_numpy()[0]
stop1 = vacation_stop1["Lat"].to_numpy()[0], vacation_stop1["Lng"].to_numpy()[0]
stop2 = vacation_stop2["Lat"].to_numpy()[0], vacation_stop2["Lng"].to_numpy()[0]
stop3 = vacation_stop3["Lat"].to_numpy()[0], vacation_stop3["Lng"].to_numpy()[0]

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".

fig = gmaps.figure()
vacation_itinerary = gmaps.directions_layer(
    start, end, waypoints=[stop1,stop2,stop3],
                travel_mode="DRIVING")
fig.add_layer(full_route)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start, vacation_end, vacation_stop1, vacation_stop2, vacation_stop3],ignore_index=True)
itinerary_df
# Out:
#     City_ID       City Country  Max Temp Current Description      Lat  \
# 0        39   Thompson      CA     74.28              Clouds  55.7435
# 1        81   Thompson      CA     74.28              Clouds  55.7435
# 2       123   Thompson      CA     74.28              Clouds  55.7435
# 3        39   Thompson      CA     74.28              Clouds  55.7435
# 4        81   Thompson      CA     74.28              Clouds  55.7435
# 5       123   Thompson      CA     74.28              Clouds  55.7435
# 6        28  Eganville      CA     73.51              Clouds  45.5334
# 7        70  Eganville      CA     73.51              Clouds  45.5334
# 8       112  Eganville      CA     73.51              Clouds  45.5334
# 9        43  Jamestown      US     74.84              Clouds  42.0970
# 10       85  Jamestown      US     74.84              Clouds  42.0970
# 11      127  Jamestown      US     74.84              Clouds  42.0970
# 12      137     Lompoc      US     83.70              Clouds  34.6391
#
#          Lng                                Hotel Name
# 0   -97.8558                           Burntwood Hotel
# 1   -97.8558                           Burntwood Hotel
# 2   -97.8558                           Burntwood Hotel
# 3   -97.8558                           Burntwood Hotel
# 4   -97.8558                           Burntwood Hotel
# 5   -97.8558                           Burntwood Hotel
# 6   -77.0994                                  Egan Inn
# 7   -77.0994                                  Egan Inn
# 8   -77.0994                                  Egan Inn
# 9   -79.2353            Hampton Inn & Suites Jamestown
# 10  -79.2353            Hampton Inn & Suites Jamestown
# 11  -79.2353            Hampton Inn & Suites Jamestown
# 12 -120.4579  Holiday Inn Express Lompoc, an IHG Hotel

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """

<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp} °F</dd>
</dl>

"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
locations = itinerary_df[["Lat", "Lng"]]
max_temp = itinerary_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 4b. Display the figure
map = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig = gmaps.figure()
fig.add_layer(map)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
